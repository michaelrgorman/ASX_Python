# %%
#https://www.youtube.com/watch?v=t_vZDyQDUkk
import datetime as dt
import pandas as pd
from pandas_datareader import data as pdr

# %%
end = dt.datetime.now()
start = dt.datetime(2000,1,1)
start, end
# Out:
# (datetime.datetime(2000, 1, 1, 0, 0),
#  datetime.datetime(2021, 9, 1, 10, 28, 51, 980226))

# %%
stockList = ['CBA', 'NAB', 'ANZ', 'BOQ', 'BEN', 'WBC']
stocks = [i + '.AX' for i in stockList]
stocks
# Out:
# ['CBA.AX', 'NAB.AX', 'ANZ.AX', 'BOQ.AX', 'BEN.AX', 'WBC.AX']

# %%
df = pdr.get_data_yahoo(stocks, start, end)
df.head()
# Out:
# Attributes Adj Close                                                    \
# Symbols       CBA.AX    NAB.AX    ANZ.AX    BOQ.AX    BEN.AX    WBC.AX
# Date
# 2000-01-02  8.136428  6.559452  3.489121  1.694236  1.493924  3.528851
# 2000-01-03  8.043367  6.334234  3.362856  1.674107  1.473499  3.462687
# 2000-01-04  7.863455  6.207550  3.271541  1.669075  1.482252  3.398873
# 2000-01-05  7.708358  6.109015  3.189990  1.677462  1.461828  3.392156
# 2000-01-06  7.785907  6.162506  3.233757  1.664042  1.488088  3.392156
#
# Attributes      Close                                  ...       Open  \
# Symbols        CBA.AX     NAB.AX     ANZ.AX    BOQ.AX  ...     ANZ.AX
# Date                                                   ...
# 2000-01-02  26.088652  22.164883  10.586787  4.674849  ...  10.586787
# 2000-01-03  25.790268  21.403856  10.203672  4.619306  ...  10.394752
# 2000-01-04  25.213392  20.975779   9.926606  4.605421  ...   9.983930
# 2000-01-05  24.716087  20.642830   9.679157  4.628563  ...   9.983930
# 2000-01-06  24.964741  20.823574   9.811958  4.591535  ...   9.745080
#
# Attributes                                    Volume                        \
# Symbols       BOQ.AX    BEN.AX     WBC.AX     CBA.AX     NAB.AX     ANZ.AX
# Date
# 2000-01-02  4.674849  5.060608  10.435952        0.0        0.0        0.0
# 2000-01-03  4.673923  5.090260  10.448864  1018072.0  3005390.0  3310622.0
# 2000-01-04  4.588758  4.963745  10.063487  2191283.0  4604126.0  6209608.0
# 2000-01-05  4.628563  4.979559  10.081366  1505531.0  2574906.0  6683860.0
# 2000-01-06  4.628563  4.991420  10.031704  1414040.0  3028993.0  3479904.0
#
# Attributes
# Symbols       BOQ.AX   BEN.AX     WBC.AX
# Date
# 2000-01-02       0.0      0.0        0.0
# 2000-01-03  132682.0  30457.0  2324971.0
# 2000-01-04   70769.0  46877.0  2456811.0
# 2000-01-05  153240.0  37649.0  4354261.0
# 2000-01-06   63727.0  34951.0  2360114.0
#
# [5 rows x 36 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#                '2000-01-06', '2000-01-09', '2000-01-10', '2000-01-11',
#                '2000-01-12', '2000-01-13',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=5518, freq=None)

# %%
df.columns
# Out:
# MultiIndex([('Adj Close', 'CBA.AX'),
#             ('Adj Close', 'NAB.AX'),
#             ('Adj Close', 'ANZ.AX'),
#             ('Adj Close', 'BOQ.AX'),
#             ('Adj Close', 'BEN.AX'),
#             ('Adj Close', 'WBC.AX'),
#             (    'Close', 'CBA.AX'),
#             (    'Close', 'NAB.AX'),
#             (    'Close', 'ANZ.AX'),
#             (    'Close', 'BOQ.AX'),
#             (    'Close', 'BEN.AX'),
#             (    'Close', 'WBC.AX'),
#             (     'High', 'CBA.AX'),
#             (     'High', 'NAB.AX'),
#             (     'High', 'ANZ.AX'),
#             (     'High', 'BOQ.AX'),
#             (     'High', 'BEN.AX'),
#             (     'High', 'WBC.AX'),
#             (      'Low', 'CBA.AX'),
#             (      'Low', 'NAB.AX'),
#             (      'Low', 'ANZ.AX'),
#             (      'Low', 'BOQ.AX'),
#             (      'Low', 'BEN.AX'),
#             (      'Low', 'WBC.AX'),
#             (     'Open', 'CBA.AX'),
#             (     'Open', 'NAB.AX'),
#             (     'Open', 'ANZ.AX'),
#             (     'Open', 'BOQ.AX'),
#             (     'Open', 'BEN.AX'),
#             (     'Open', 'WBC.AX'),
#             (   'Volume', 'CBA.AX'),
#             (   'Volume', 'NAB.AX'),
#             (   'Volume', 'ANZ.AX'),
#             (   'Volume', 'BOQ.AX'),
#             (   'Volume', 'BEN.AX'),
#             (   'Volume', 'WBC.AX')],
#            names=['Attributes', 'Symbols'])

# %%
Close = df.Close
Close.head()
# Out:
# Symbols        CBA.AX     NAB.AX     ANZ.AX    BOQ.AX    BEN.AX     WBC.AX
# Date
# 2000-01-02  26.088652  22.164883  10.586787  4.674849  5.060608  10.435952
# 2000-01-03  25.790268  21.403856  10.203672  4.619306  4.991420  10.240284
# 2000-01-04  25.213392  20.975779   9.926606  4.605421  5.021072  10.051568
# 2000-01-05  24.716087  20.642830   9.679157  4.628563  4.951884  10.031704
# 2000-01-06  24.964741  20.823574   9.811958  4.591535  5.040840  10.031704

# %%
Close.describe()
# Out:
# Symbols       CBA.AX       NAB.AX       ANZ.AX       BOQ.AX       BEN.AX  \
# count    5518.000000  5487.000000  5487.000000  5485.000000  5485.000000
# mean       54.931654    28.064360    23.316594     9.943851     9.820715
# std        20.788594     4.899235     5.891964     3.036466     2.440526
# min        22.418535    13.880000     9.334258     4.466409     4.566408
# 25%        33.331908    24.629352    18.141522     7.404942     8.100000
# 50%        51.868973    27.986731    23.709999     9.876538     9.910000
# 75%        74.606461    31.325733    28.120001    12.100000    11.376440
# max       108.169998    42.655506    37.189999    18.346272    17.791132
#
# Symbols       WBC.AX
# count    5486.000000
# mean       23.331833
# std         6.599798
# min        10.031704
# 25%        17.600178
# 50%        23.331161
# 75%        28.803904
# max        39.620266

# %%
Close[Close.index > end - dt.timedelta(days = 100)].describe()
# Out:
# Symbols      CBA.AX     NAB.AX     ANZ.AX     BOQ.AX     BEN.AX     WBC.AX
# count     71.000000  71.000000  71.000000  71.000000  71.000000  70.000000
# mean     100.643239  26.655775  28.288873   9.089014  10.354648  25.711429
# std        2.239461   0.612934   0.500658   0.220403   0.295721   0.663345
# min       97.610001  25.469999  27.150000   8.740000   9.800000  24.520000
# 25%       99.189999  26.135000  27.985000   8.915000  10.195000  25.285000
# 50%       99.870003  26.620001  28.280001   9.010000  10.330000  25.795000
# 75%      101.510002  27.105000  28.670000   9.260000  10.525000  26.190001
# max      108.169998  27.730000  29.530001   9.580000  11.100000  26.940001

# %%
Close.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)
pd.options.plotting.backend = 'plotly'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.3.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
Close.plot()

# %%
Close['CBA.AX'].pct_change().plot(kind='hist')
